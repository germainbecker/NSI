# %% [markdown]
# # Algorithmes gloutons - EXERCICES
#
# Un algorithme glouton permet d'apporter une solution à un problème d'optimisation (*maximiser* ou *minimiser* une grandeur) tout en respectant certaines *contraintes*.
#
#
# ## Exercice 1
#
# On cherche à sélectionner cinq nombres de la liste suivante en cherchant à avoir leur somme la plus grande possible (maximiser une grandeur) et en s'interdisant de choisir deux nombres voisins (contrainte).
#
# | <!-- --> | <!-- --> | <!-- --> | <!-- --> | <!-- --> | <!-- --> | <!-- --> | <!-- --> | <!-- --> | <!-- --> | <!-- --> | <!-- --> | <!-- --> | <!-- --> | <!-- --> | <!-- --> | <!-- --> | <!-- --> | <!-- --> | <!-- --> |
# |---| --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | 15 | 4 | 20 |	17 | 11 | 8 | 11 | 16 |	7 | 14 | 2 | 7 | 5 | 17 | 19 | 18 |	4 |	5 |	13 | 8 |
#
# Comme on souhaite avoir le plus grand résultat final, la stratégie gloutonne consiste à choisir à chaque étape le plus grand nombre possible dans les choix restants.
#
# 1. Appliquez cet algorithme glouton sur le tableau.
# 2. Vérifiez que $\{20, 18, 17, 16, 15\}$ est une autre solution possible.
# 3. Que dire de la solution gloutonne ?

# %% [markdown]
# ## Exercice 2 : le problème du voyageur
#
# Un voyageur a ciblé plusieurs villes qu'il souhaite visiter. Il cherche un itinéraire passant par toutes ces villes et qui minimise la distance totale parcourue. Les villes peuvent être visitées dans n'importe quel ordre mais aucune ne doit être négligée, et le visiteur doit revenir à la fin à sa ville de départ.
#
# Le voyageur part de Nancy et souhaite visiter Metz, Paris, Reims et Troyes, avant de retourner à Nancy.
#
# Voici un tableau donnant les distances kilométriques entre chacune des ces villes.
#
# ![tableau des distances](data/tableau_voyageur.png)
#
# 1. Quelle est la stratégie gloutonne à mettre en oeuvre ?
# 2. Mettez en oeuvre cette stratégie et donnez la solution.
# 3. Calculez la distance totale pour le parcours Metz - Reims - Paris - Troyes (départ et arrivée à Nancy sous-entendus)
# 4. Que dire de la solution gloutonne ?

# %% [markdown]
# ## Exercice 3 : le problème du sac à dos
#
# On rappelle qu'il y a plusieurs stratégies gloutonnes pour donner une solution à ce problème
#
# - **Stratégie 1** : prendre toujours l'objet de plus grande valeur n'excédant pas la capacité restante (il faut trier préalablement par valeur décroissante)
# - **Stratégie 2** : prendre toujours l'objet de plus faible masse (il faut trier préalablement par masse croissante)
# - **Stratégie 3** : prendre toujours l'objet de plus grand rapport $\frac{\text{valeur}}{\text{masse}}$ n'excédant pas la capacité restante (il faut trier préalablement par rapport $\frac{\text{valeur}}{\text{masse}}$ décroissant)
#
# ### **Exemple 1**
#
# Considérons les objets suivants et un sac de capacité maximale 2 kg.
#
# | objet  |  A  |  B  |  C  |
# |:------:|:---:|:---:|:---:|
# |  masse (kg) |  1,5 |  2 |  0,3  |
# | valeur (€) | 200 | 500 | 400 |
# |  $\frac{\text{valeur}}{\text{masse}}$ | 133,33... | 250 | 1333,33... |
#
# 1. Appliquez chacune des stratégies à ce problème.
# 2. Quelle est la meilleure stratégie dans ce cas ?
# 3. Listez toutes les combinaisons possibles, puis celles respectant la contrainte et déduisez-en la solution optimale au problème. Comparez-la aux stratégies gloutonnes.
#
# ### **Exemple 2**
#
# Même questions mais avec un sac de capacité maximale 3,5 kg.
#
#
# ## **Exemple 3**
#
# Considérons les objets suivants et un sac de capacité maximale 2 kg.
#
# | objet  |  A  |  B  |  C  |
# |:------:|:---:|:---:|:---:|
# |  masse (kg) |  1,5 |  2 |  0,3  |
# | valeur (€) | 200 | 500 | 400 |
# |  $\frac{\text{valeur}}{\text{masse}}$ | 133,33... | 250 | 1333,33... |
#
# Correction : Ex 3 qu
#
# - la stratégie 1 (choix par valeur décroissante) donne le sac $\{B\}$ d'une valeur de 500 € ;
# - la stratégie 2 (choix par masse croissante) donne le sac $\{C, A\}$ d'une valeur de 600 € ;
# - la stratégie 3 (choix par rapport valeur/masse décroissante) donne le sac $\{C, A\}$ d'une valeur de 600 €.
#
# Les stratégies 2 et 3 sont meilleures et donnent dans ce cas la solution optimale.
#
#
#
# - la stratégie 1 (choix par valeur décroissante) donne le sac $\{B, C\}$ d'une valeur de 900 € ;
# - la stratégie 2 (choix par masse croissante) donne le sac $\{C, A\}$ d'une valeur de 600 € ;
# - la stratégie 3 (choix par rapport valeur/masse décroissante) donne le sac $\{C, B\}$ d'une valeur de 900 €.
#
# Cette fois-ci, ce sont les stratégies 1 et 3 qui sont meilleures et donnent dans ce cas la solution optimale.

# %% [markdown]
# ## Exercice 4
#
# >**Objectifs** :
# - implémenter un algorithme glouton pour trouver une solution à un problème
# - implémenter l'algorithme de *force brute* pour déterminer la solution optimale et la comparer à la solution gloutonne
#
# ### Introduction
#
# Nous disposons d’une clé USB qui est déjà bien remplie et sur laquelle il ne reste que 8 Go de libre. Nous souhaitons copier sur cette  clé  des  fichiers  vidéos  pour  l’emporter  en  voyage.  Chaque  fichier  a  un poids  et  chaque  vidéo  a  une  durée.  La  durée  n’est pas proportionnelle à la taille car les fichiers sont de format différents, certaines vidéos sont de grande qualité, d’autres sont très compressées. Le tableau qui suit présente les 10 fichiers disponibles avec les durées données en minutes.
#
# | Nom 	| Durée en min (valeur) 	| Poids |
# |---------	|-------	|---------	|
# | Vidéo A 	| 114   	| 4.5 Go 	|
# | Vidéo B 	| 85    	| 630 Mo  	|
# | Vidéo C 	| 40    	| 3.35 Go 	|
# | Vidéo D 	| 4     	| 85 Mo   	|
# | Vidéo E 	| 18    	| 2,15 Go 	|
# | Vidéo F 	| 80    	| 2,71 Go 	|
# | Vidéo G 	| 5     	| 320 Mo  	|
# | Vidéo H 	| 86    	| 3.7 Go  	|
# | Vidéo I 	| 64     	| 2.4 Go  	|
# | Vidéo J 	| 12     	| 6.4 Go  	|
#
# >**Problème** : Quelles vidéos copier sur la clé USB pour que la durée des vidéos soient la plus grande possible tout en ne dépassant pas 8 Go ?
#
# **Question 1** : Quelle est la valeur que l'on cherche à maximiser/minimiser ? Quelle est la contrainte ?
#
# **Question 2** : Quel problème reconnaissez-vous ici ?
#
# >**Notation** : Dans la suite, on identifiera la *durée* d'une vidéo à sa *valeur* pour garder le même vocabulaire que dans le cours.
#
# Vous allez implémenter (= programmer) une solution gloutonne pour résoudre ce problème, puis vous implémenterez l'algorithme de *force brute* qui donnera la solution optimale au problème. La stratégie gloutonne retenue sera de toujours prendre la vidéo de plus grand rapport $\frac{\text{valeur}}{\text{poids}}$ n'excédant pas la capacité restante.
#
# ### Représentation des données
#
# On utilise un dictionnaire pour représenter une vidéo, la valeur étant la durée en minute et le poids étant donné en Go.
#
# ```python
# {'nom': 'Vidéo A', 'valeur': 114, 'poids': 4.57}
# ```
#
# On peut alors mémoriser les 10 vidéos dans le tableau `table_videos` suivant.

# %%
table_videos = [{'nom' : 'video A', 'valeur' : 114, 'poids' : 4.5},
                {'nom' : 'video B', 'valeur' : 85, 'poids' : 0.63},
                {'nom' : 'video C', 'valeur' : 40, 'poids' : 3.35},
                {'nom' : 'video D', 'valeur' : 4, 'poids' : 0.085},
                {'nom' : 'video E', 'valeur' : 18, 'poids' : 2.15},
                {'nom' : 'video F', 'valeur' : 80, 'poids' : 2.71},
                {'nom' : 'video G', 'valeur' : 5, 'poids' : 0.32},
                {'nom' : 'video H', 'valeur' : 74, 'poids' : 3.7},
                {'nom' : 'video I', 'valeur' : 64, 'poids' : 2.4},
                {'nom' : 'video J', 'valeur' : 12, 'poids' : 6.4}]

# %% [markdown]
# On peut alors accéder aux éléments de cette table.

# %%
table_videos[0]['nom']
# Out:
# 'video A'

# %%
table_videos[3]['valeur']
# Out:
# 4

# %%
table_videos[9]['poids']
# Out:
# 6.4

# %% [markdown]
# ### Ecriture des fonctions utiles
#
# #### Accès au poids d'une vidéo
#
# Pour résoudre le problème, on a besoin d'accéder au poids des vidéos pour vérifier la contrainte du poids maximal. La fonction suivante permet de renvoyer le poids d'une vidéo entrée en paramètre (sous la forme d'un dictionnaire vu précédemment). Quelques assertions devant être vérifiées par la fonction ont été écrites.

# %%
def poids(video):
    return video['poids']

assert poids({'nom' : 'video A', 'valeur' : 114, 'poids' : 4.5}) == 4.5
assert poids({'nom' : 'video D', 'valeur' : 4, 'poids' : 0.085}) == 0.085
assert poids({'nom' : 'video J', 'valeur' : 12, 'poids' : 6.4}) == 6.4

# %% [markdown]
# #### Accès à la durée d'une vidéo
#
# De même, pour connaître la durée totale d'une solution, il est nécessaire de pouvoir accéder aux durées de chacune des vidéos retenues.
#
# **Question 2** : Ecrivez une fonction `duree(video)` qui renvoie la durée (= valeur) d'une video entrée en paramètre (sous la forme d'un dictionnaire vu précédemment). Quelques assertions devant être vérifiées par votre fonction sont données ci-dessous.

# %%
def duree(video):
    # code à écrire ici
    return video['valeur']

# %%
assert duree({'nom' : 'video A', 'valeur' : 114, 'poids' : 4.5}) == 114
assert duree({'nom' : 'video D', 'valeur' : 4, 'poids' : 0.085}) == 4
assert duree({'nom' : 'video J', 'valeur' : 12, 'poids' : 6.4}) == 12

# %% [markdown]
# #### Accès au rapport $\frac{\text{valeur}}{\text{poids}}$
#
# De même, la stratégie gloutonne choisie prévoit de prendre la vidéo de plus grand rapport $\frac{\text{valeur}}{\text{poids}}$ n'excédant pas la capacité restante. Il est donc nécessaire d'accéder à cette donnée pour chaque vidéo.
#
# **Question 3** : Ecrivez une fonction `rapport_valeur_poids(video)` qui prend en paramètre une vidéo et renvoie son rapport $\frac{\text{valeur}}{\text{poids}}$. Quelques assertions devant être vérifiées par votre fonction sont données ci-dessous.

# %%
def rapport_valeur_poids(video):
    # code à écrire ici
    return duree(video)/poids(video)  # ou video['valeur']/video['poids']

# %%
assert rapport_valeur_poids({'nom' : 'video H', 'valeur' : 74, 'poids' : 3.7}) ==  20
assert rapport_valeur_poids({'nom' : 'video J', 'valeur' : 12, 'poids' : 6.4}) == 1.875
# vous remarquerez que l'on a pris soin de sélectionner les vidéos dont le rapport peut être représenté de manière exacte en machine

# %% [markdown]
# Enfin, comme le choix se fait par rapport $\frac{\text{valeur}}{\text{poids}}$ décroissant, il est judicieux de trier au préalable les vidéos par ordre décroissant selon ce rapport.
#
# **Question 4** : Ecrivez une fonction `tri_rapport_decroissant(table_videos)` qui renvoie un *nouveau tableau* dans lequel les fichiers ont été triés par rapport $\frac{\text{valeur}}{\text{poids}}$ décroissant. Quelques assertions devant être vérifiées par votre fonction sont données ci-dessous.
#
# *Indications* : l'instruction `help(sorted)` vous permet d'afficher l'aide de la fonction `sorted`. Si besoin, revoir le notebook sur le tri d'une table (Séquence 5, Chapitre 1, Activité 2).

# %%
help(sorted)
# Out:
# Help on built-in function sorted in module builtins:
#
# sorted(iterable, /, *, key=None, reverse=False)
#     Return a new list containing all items from the iterable in ascending order.
#
#     A custom key function can be supplied to customize the sort order, and the
#     reverse flag can be set to request the result in descending order.

# %%
def tri_rapport_decroissant(table_videos):
    table_triee = sorted(table_videos, key = rapport_valeur_poids, reverse = True)
    return table_triee

def tri_valeur_decroissante(tables_videos):
    table_triee = sorted(table_videos, key = duree, reverse = True)
    return table_triee

def tri_poids_croissant(tables_videos):
    table_triee = sorted(table_videos, key = poids)
    return table_triee

# %%
assert tri_rapport_decroissant(table_videos) == [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
                                                 {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
                                                 {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
                                                 {'nom': 'video I', 'valeur': 64, 'poids': 2.4},
                                                 {'nom': 'video A', 'valeur': 114, 'poids': 4.5},
                                                 {'nom': 'video H', 'valeur': 74, 'poids': 3.7},
                                                 {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
                                                 {'nom': 'video C', 'valeur': 40, 'poids': 3.35},
                                                 {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
                                                 {'nom': 'video J', 'valeur': 12, 'poids': 6.4}]

# %% [markdown]
# #### Calculer le poids total et la durée totale d'une table de vidéos
#
# Enfin, il sera nécessaire de pouvoir calculer le poids et la durée totale d'une table de vidéos pour savoir si la contrainte de capacité maximale est respectée d'une part, et pour connaître la durée totale qui est la valeur à maximiser.
#
# **Question 5** : Ecrivez une fonction `poids_total(table_videos)` qui renvoie le poids total des vidéos présentes dans `table_videos`. Quelques assertions devant être vérifiées par votre fonction sont données ci-dessous.

# %%
def poids_total(table_videos):
    poids_t = 0
    for video in table_videos:
        poids_t = poids_t + video['poids']
    return poids_t

# %%
table1 = [{'nom': 'video J', 'poids': 6.4, 'valeur': 12}]
table2 = [{'nom': 'video A', 'poids': 4.5, 'valeur': 114},
           {'nom': 'video J', 'poids': 6.4, 'valeur': 12}]
table3 = [{'nom': 'video A', 'poids': 4.5, 'valeur': 114},
          {'nom': 'video B', 'poids': 0.63, 'valeur': 85},
          {'nom': 'video D', 'poids': 0.085, 'valeur': 4}]

assert poids_total(table1) == 6.4   # on compare des nombres réels mais on a pris soin de bien choisir les exemples
assert poids_total(table2) == 10.9
assert poids_total(table3) == 5.215
assert poids_total([]) == 0   # table vide testée

# %% [markdown]
# **Question 6** : Ecrivez une fonction `duree_totale(table_videos)` qui renvoie la durée totale des vidéos présentes dans `table_videos`. Quelques assertions devant être vérifiées par votre fonction sont données ci-dessous.

# %%
def duree_totale(table_videos):
    duree_t = 0
    for video in table_videos:
        duree_t = duree_t + video['valeur']
    return duree_t

# %%
table1 = [{'nom': 'video J', 'poids': 6.4, 'valeur': 12}]
table2 = [{'nom': 'video A', 'poids': 4.5, 'valeur': 114},
           {'nom': 'video J', 'poids': 6.4, 'valeur': 12}]
table3 = [{'nom': 'video A', 'poids': 4.5, 'valeur': 114},
          {'nom': 'video B', 'poids': 0.63, 'valeur': 85},
          {'nom': 'video D', 'poids': 0.085, 'valeur': 4}]

assert duree_totale(table1) == 12
assert duree_totale(table2) == 126
assert duree_totale(table3) == 203
assert duree_totale([]) == 0   # table vide testée
assert duree_totale(table_videos) == 496 # table avec toutes les vidéos

# %% [markdown]
# ### Implémentation de l'algorithme glouton
#
# **Question 7** : en vous inspirant de l'implémentation de l'algorithme glouton du rendu de monnaie (voir cours), écrivez une fonction `glouton(table_videos, poids_max)` qui prend en paramètre une table de vidéos `table_videos` et un poids maximal `poids_max` et renvoie une table `solution_gloutonne` contenant la solution gloutonne au problème. La solution gloutonne est donnée dans l'assertion qui suit.

# %%
def glouton(table_videos, poids_max):
    table_triee = tri_poids_croissant(table_videos)
    poids_total = 0
    solution_gloutonne = []
    # à compléter
    i = 0
    while poids_total < poids_max and i < len(table_triee):  # tant que le poids max n'est pas atteint et que l'on n'a pas traité toutes les vidéos
        video = table_triee[i]
        poids_video = poids(video)
        if poids_total + poids_video <= poids_max:  # on ajoute la vidéo d'indice i à notre solution
            solution_gloutonne.append(video)
            poids_total = poids_total + poids_video  # on met à jour le poids total de note solution
        i = i + 1
    return solution_gloutonne

# %%
glouton(table_videos, 8)
# Out:
# [{'nom': 'video D', 'valeur': 4, 'poids': 0.085},
#  {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
#  {'nom': 'video B', 'valeur': 85, 'poids': 0.63},
#  {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
#  {'nom': 'video I', 'valeur': 64, 'poids': 2.4}]

# %%
assert glouton(table_videos, 8) == [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
                                    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
                                    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
                                    {'nom': 'video I', 'valeur': 64, 'poids': 2.4},
                                    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}]

# %% [markdown]
# **Question 8** : Quel est le poids total de la solution gloutonne ? Quelle est sa durée totale ?

# %%
# à compléter
solution_gloutonne = glouton(table_videos, 8)
print("poids total :", poids_total(solution_gloutonne), "Go")
print("durée totale :", duree_totale(solution_gloutonne), "min")
# Out:
# poids total : 6.145 Go
# durée totale : 238 min

# %% [markdown]
# ### Implémentation de la *force brute*
#
# Le principe est simple : il faut étudier tous les cas possibles. Ainsi, pour appliquer cette stratégie, il faut :
# 1. d'abord *énumérer* toutes les combinaisons possibles de vidéos
# 2. puis conserver celles dont la capacité maximale n'est pas dépassée
# 3. enfin, trouver la meilleure solution parmi les combinaisons restantes
#
# #### Etape 1 : énumération de toutes les combinaisons
#
# Il s'agit de la difficulté majeure. Dans un combinaison de vidéos, chaque vidéo de départ est prise ou non, il s'agit d'une donnée binaire. Ainsi, une approche consiste à créer des mots binaires représentant chaque combinaison. Par exemple, le mot '1101000001' signifie qu'on prend les vidéos A, B, D et J tandis que le mot '1111111111' signifie que l'on prend toutes les vidéos.
#
# Dans notre exemple, nous avons 10 vidéos donc il y a $2^{10} = 1024$ combinaisons possibles. De manière générale il y a donc $2^n$ combinaisons pour un ensemble de $n$ vidéos.
#
# Pour obtenir notre liste de mots binaires, on peut parcourir tous les entiers compris entre $0$ et $2^n-1$, les convertir en binaire et les ajouter à une liste appelée `combinaisons`.
#
# >**Astuce** : la fonction `bin` prend un entier en paramètre et renvoie sa valeur binaire sous forme d'une chaîne de caractères. Par exemple, `bin(12)` renvoie la chaîne `'0b1101'`. Il suffira de supprimer les caractères `'0b'` en tête pour obtenir l'écriture binaire. On veillera également à compléter avec des zéros devant pour obtenir un mot de la longueur désirée.
#
# La fonction `table_combinaisons` suivante prend en paramètre une table de vidéos et renvoie une liste `combinaisons` contenant tous les mots binaires correspondant aux différentes combinaisons possibles de vidéos dans `table_videos`.

# %%
def table_combinaisons(table_videos):
    n = len(table_videos)  # nombre de vidéos
    table_entiers = [i for i in range(2**n)]  # création d'un tableau avec tous les entiers entre 0 et 2**n-1
    #print(table_entiers)
    table_binaire = [bin(i)[2:] for i in table_entiers]  # conversion binaire des entiers du tableau précédent, le [2:] permet de supprimer les caractères de tête '0b' renvoyés par la fonction bin
    #print(table_binaire)
    combinaisons = ['0'*(n-len(k)) + k for k in table_binaire]  # ajout des zéros pour obtenir des mots binaires de longueur n
    return combinaisons

# %% [markdown]
# On peut vérifier que sur notre exemple, cette fonction renvoie bien un tableau avec tous les mots binaires de longueur 10. Je vous encourage à décommenter les lignes avec les affichages pour voir le contenu de chaque tableau.

# %%
table_combinaisons(table_videos)
# Out:
# ['0000000000',
#  '0000000001',
#  '0000000010',
#  '0000000011',
#  '0000000100',
#  '0000000101',
#  '0000000110',
#  '0000000111',
#  '0000001000',
#  '0000001001',
#  '0000001010',
#  '0000001011',
#  '0000001100',
#  '0000001101',
#  '0000001110',
#  '0000001111',
#  '0000010000',
#  '0000010001',
#  '0000010010',
#  '0000010011',
#  '0000010100',
#  '0000010101',
#  '0000010110',
#  '0000010111',
#  '0000011000',
#  '0000011001',
#  '0000011010',
#  '0000011011',
#  '0000011100',
#  '0000011101',
#  '0000011110',
#  '0000011111',
#  '0000100000',
#  '0000100001',
#  '0000100010',
#  '0000100011',
#  '0000100100',
#  '0000100101',
#  '0000100110',
#  '0000100111',
#  '0000101000',
#  '0000101001',
#  '0000101010',
#  '0000101011',
#  '0000101100',
#  '0000101101',
#  '0000101110',
#  '0000101111',
#  '0000110000',
#  '0000110001',
#  '0000110010',
#  '0000110011',
#  '0000110100',
#  '0000110101',
#  '0000110110',
#  '0000110111',
#  '0000111000',
#  '0000111001',
#  '0000111010',
#  '0000111011',
#  '0000111100',
#  '0000111101',
#  '0000111110',
#  '0000111111',
#  '0001000000',
#  '0001000001',
#  '0001000010',
#  '0001000011',
#  '0001000100',
#  '0001000101',
#  '0001000110',
#  '0001000111',
#  '0001001000',
#  '0001001001',
#  '0001001010',
#  '0001001011',
#  '0001001100',
#  '0001001101',
#  '0001001110',
#  '0001001111',
#  '0001010000',
#  '0001010001',
#  '0001010010',
#  '0001010011',
#  '0001010100',
#  '0001010101',
#  '0001010110',
#  '0001010111',
#  '0001011000',
#  '0001011001',
#  '0001011010',
#  '0001011011',
#  '0001011100',
#  '0001011101',
#  '0001011110',
#  '0001011111',
#  '0001100000',
#  '0001100001',
#  '0001100010',
#  '0001100011',
#  '0001100100',
#  '0001100101',
#  '0001100110',
#  '0001100111',
#  '0001101000',
#  '0001101001',
#  '0001101010',
#  '0001101011',
#  '0001101100',
#  '0001101101',
#  '0001101110',
#  '0001101111',
#  '0001110000',
#  '0001110001',
#  '0001110010',
#  '0001110011',
#  '0001110100',
#  '0001110101',
#  '0001110110',
#  '0001110111',
#  '0001111000',
#  '0001111001',
#  '0001111010',
#  '0001111011',
#  '0001111100',
#  '0001111101',
#  '0001111110',
#  '0001111111',
#  '0010000000',
#  '0010000001',
#  '0010000010',
#  '0010000011',
#  '0010000100',
#  '0010000101',
#  '0010000110',
#  '0010000111',
#  '0010001000',
#  '0010001001',
#  '0010001010',
#  '0010001011',
#  '0010001100',
#  '0010001101',
#  '0010001110',
#  '0010001111',
#  '0010010000',
#  '0010010001',
#  '0010010010',
#  '0010010011',
#  '0010010100',
#  '0010010101',
#  '0010010110',
#  '0010010111',
#  '0010011000',
#  '0010011001',
#  '0010011010',
#  '0010011011',
#  '0010011100',
#  '0010011101',
#  '0010011110',
#  '0010011111',
#  '0010100000',
#  '0010100001',
#  '0010100010',
#  '0010100011',
#  '0010100100',
#  '0010100101',
#  '0010100110',
#  '0010100111',
#  '0010101000',
#  '0010101001',
#  '0010101010',
#  '0010101011',
#  '0010101100',
#  '0010101101',
#  '0010101110',
#  '0010101111',
#  '0010110000',
#  '0010110001',
#  '0010110010',
#  '0010110011',
#  '0010110100',
#  '0010110101',
#  '0010110110',
#  '0010110111',
#  '0010111000',
#  '0010111001',
#  '0010111010',
#  '0010111011',
#  '0010111100',
#  '0010111101',
#  '0010111110',
#  '0010111111',
#  '0011000000',
#  '0011000001',
#  '0011000010',
#  '0011000011',
#  '0011000100',
#  '0011000101',
#  '0011000110',
#  '0011000111',
#  '0011001000',
#  '0011001001',
#  '0011001010',
#  '0011001011',
#  '0011001100',
#  '0011001101',
#  '0011001110',
#  '0011001111',
#  '0011010000',
#  '0011010001',
#  '0011010010',
#  '0011010011',
#  '0011010100',
#  '0011010101',
#  '0011010110',
#  '0011010111',
#  '0011011000',
#  '0011011001',
#  '0011011010',
#  '0011011011',
#  '0011011100',
#  '0011011101',
#  '0011011110',
#  '0011011111',
#  '0011100000',
#  '0011100001',
#  '0011100010',
#  '0011100011',
#  '0011100100',
#  '0011100101',
#  '0011100110',
#  '0011100111',
#  '0011101000',
#  '0011101001',
#  '0011101010',
#  '0011101011',
#  '0011101100',
#  '0011101101',
#  '0011101110',
#  '0011101111',
#  '0011110000',
#  '0011110001',
#  '0011110010',
#  '0011110011',
#  '0011110100',
#  '0011110101',
#  '0011110110',
#  '0011110111',
#  '0011111000',
#  '0011111001',
#  '0011111010',
#  '0011111011',
#  '0011111100',
#  '0011111101',
#  '0011111110',
#  '0011111111',
#  '0100000000',
#  '0100000001',
#  '0100000010',
#  '0100000011',
#  '0100000100',
#  '0100000101',
#  '0100000110',
#  '0100000111',
#  '0100001000',
#  '0100001001',
#  '0100001010',
#  '0100001011',
#  '0100001100',
#  '0100001101',
#  '0100001110',
#  '0100001111',
#  '0100010000',
#  '0100010001',
#  '0100010010',
#  '0100010011',
#  '0100010100',
#  '0100010101',
#  '0100010110',
#  '0100010111',
#  '0100011000',
#  '0100011001',
#  '0100011010',
#  '0100011011',
#  '0100011100',
#  '0100011101',
#  '0100011110',
#  '0100011111',
#  '0100100000',
#  '0100100001',
#  '0100100010',
#  '0100100011',
#  '0100100100',
#  '0100100101',
#  '0100100110',
#  '0100100111',
#  '0100101000',
#  '0100101001',
#  '0100101010',
#  '0100101011',
#  '0100101100',
#  '0100101101',
#  '0100101110',
#  '0100101111',
#  '0100110000',
#  '0100110001',
#  '0100110010',
#  '0100110011',
#  '0100110100',
#  '0100110101',
#  '0100110110',
#  '0100110111',
#  '0100111000',
#  '0100111001',
#  '0100111010',
#  '0100111011',
#  '0100111100',
#  '0100111101',
#  '0100111110',
#  '0100111111',
#  '0101000000',
#  '0101000001',
#  '0101000010',
#  '0101000011',
#  '0101000100',
#  '0101000101',
#  '0101000110',
#  '0101000111',
#  '0101001000',
#  '0101001001',
#  '0101001010',
#  '0101001011',
#  '0101001100',
#  '0101001101',
#  '0101001110',
#  '0101001111',
#  '0101010000',
#  '0101010001',
#  '0101010010',
#  '0101010011',
#  '0101010100',
#  '0101010101',
#  '0101010110',
#  '0101010111',
#  '0101011000',
#  '0101011001',
#  '0101011010',
#  '0101011011',
#  '0101011100',
#  '0101011101',
#  '0101011110',
#  '0101011111',
#  '0101100000',
#  '0101100001',
#  '0101100010',
#  '0101100011',
#  '0101100100',
#  '0101100101',
#  '0101100110',
#  '0101100111',
#  '0101101000',
#  '0101101001',
#  '0101101010',
#  '0101101011',
#  '0101101100',
#  '0101101101',
#  '0101101110',
#  '0101101111',
#  '0101110000',
#  '0101110001',
#  '0101110010',
#  '0101110011',
#  '0101110100',
#  '0101110101',
#  '0101110110',
#  '0101110111',
#  '0101111000',
#  '0101111001',
#  '0101111010',
#  '0101111011',
#  '0101111100',
#  '0101111101',
#  '0101111110',
#  '0101111111',
#  '0110000000',
#  '0110000001',
#  '0110000010',
#  '0110000011',
#  '0110000100',
#  '0110000101',
#  '0110000110',
#  '0110000111',
#  '0110001000',
#  '0110001001',
#  '0110001010',
#  '0110001011',
#  '0110001100',
#  '0110001101',
#  '0110001110',
#  '0110001111',
#  '0110010000',
#  '0110010001',
#  '0110010010',
#  '0110010011',
#  '0110010100',
#  '0110010101',
#  '0110010110',
#  '0110010111',
#  '0110011000',
#  '0110011001',
#  '0110011010',
#  '0110011011',
#  '0110011100',
#  '0110011101',
#  '0110011110',
#  '0110011111',
#  '0110100000',
#  '0110100001',
#  '0110100010',
#  '0110100011',
#  '0110100100',
#  '0110100101',
#  '0110100110',
#  '0110100111',
#  '0110101000',
#  '0110101001',
#  '0110101010',
#  '0110101011',
#  '0110101100',
#  '0110101101',
#  '0110101110',
#  '0110101111',
#  '0110110000',
#  '0110110001',
#  '0110110010',
#  '0110110011',
#  '0110110100',
#  '0110110101',
#  '0110110110',
#  '0110110111',
#  '0110111000',
#  '0110111001',
#  '0110111010',
#  '0110111011',
#  '0110111100',
#  '0110111101',
#  '0110111110',
#  '0110111111',
#  '0111000000',
#  '0111000001',
#  '0111000010',
#  '0111000011',
#  '0111000100',
#  '0111000101',
#  '0111000110',
#  '0111000111',
#  '0111001000',
#  '0111001001',
#  '0111001010',
#  '0111001011',
#  '0111001100',
#  '0111001101',
#  '0111001110',
#  '0111001111',
#  '0111010000',
#  '0111010001',
#  '0111010010',
#  '0111010011',
#  '0111010100',
#  '0111010101',
#  '0111010110',
#  '0111010111',
#  '0111011000',
#  '0111011001',
#  '0111011010',
#  '0111011011',
#  '0111011100',
#  '0111011101',
#  '0111011110',
#  '0111011111',
#  '0111100000',
#  '0111100001',
#  '0111100010',
#  '0111100011',
#  '0111100100',
#  '0111100101',
#  '0111100110',
#  '0111100111',
#  '0111101000',
#  '0111101001',
#  '0111101010',
#  '0111101011',
#  '0111101100',
#  '0111101101',
#  '0111101110',
#  '0111101111',
#  '0111110000',
#  '0111110001',
#  '0111110010',
#  '0111110011',
#  '0111110100',
#  '0111110101',
#  '0111110110',
#  '0111110111',
#  '0111111000',
#  '0111111001',
#  '0111111010',
#  '0111111011',
#  '0111111100',
#  '0111111101',
#  '0111111110',
#  '0111111111',
#  '1000000000',
#  '1000000001',
#  '1000000010',
#  '1000000011',
#  '1000000100',
#  '1000000101',
#  '1000000110',
#  '1000000111',
#  '1000001000',
#  '1000001001',
#  '1000001010',
#  '1000001011',
#  '1000001100',
#  '1000001101',
#  '1000001110',
#  '1000001111',
#  '1000010000',
#  '1000010001',
#  '1000010010',
#  '1000010011',
#  '1000010100',
#  '1000010101',
#  '1000010110',
#  '1000010111',
#  '1000011000',
#  '1000011001',
#  '1000011010',
#  '1000011011',
#  '1000011100',
#  '1000011101',
#  '1000011110',
#  '1000011111',
#  '1000100000',
#  '1000100001',
#  '1000100010',
#  '1000100011',
#  '1000100100',
#  '1000100101',
#  '1000100110',
#  '1000100111',
#  '1000101000',
#  '1000101001',
#  '1000101010',
#  '1000101011',
#  '1000101100',
#  '1000101101',
#  '1000101110',
#  '1000101111',
#  '1000110000',
#  '1000110001',
#  '1000110010',
#  '1000110011',
#  '1000110100',
#  '1000110101',
#  '1000110110',
#  '1000110111',
#  '1000111000',
#  '1000111001',
#  '1000111010',
#  '1000111011',
#  '1000111100',
#  '1000111101',
#  '1000111110',
#  '1000111111',
#  '1001000000',
#  '1001000001',
#  '1001000010',
#  '1001000011',
#  '1001000100',
#  '1001000101',
#  '1001000110',
#  '1001000111',
#  '1001001000',
#  '1001001001',
#  '1001001010',
#  '1001001011',
#  '1001001100',
#  '1001001101',
#  '1001001110',
#  '1001001111',
#  '1001010000',
#  '1001010001',
#  '1001010010',
#  '1001010011',
#  '1001010100',
#  '1001010101',
#  '1001010110',
#  '1001010111',
#  '1001011000',
#  '1001011001',
#  '1001011010',
#  '1001011011',
#  '1001011100',
#  '1001011101',
#  '1001011110',
#  '1001011111',
#  '1001100000',
#  '1001100001',
#  '1001100010',
#  '1001100011',
#  '1001100100',
#  '1001100101',
#  '1001100110',
#  '1001100111',
#  '1001101000',
#  '1001101001',
#  '1001101010',
#  '1001101011',
#  '1001101100',
#  '1001101101',
#  '1001101110',
#  '1001101111',
#  '1001110000',
#  '1001110001',
#  '1001110010',
#  '1001110011',
#  '1001110100',
#  '1001110101',
#  '1001110110',
#  '1001110111',
#  '1001111000',
#  '1001111001',
#  '1001111010',
#  '1001111011',
#  '1001111100',
#  '1001111101',
#  '1001111110',
#  '1001111111',
#  '1010000000',
#  '1010000001',
#  '1010000010',
#  '1010000011',
#  '1010000100',
#  '1010000101',
#  '1010000110',
#  '1010000111',
#  '1010001000',
#  '1010001001',
#  '1010001010',
#  '1010001011',
#  '1010001100',
#  '1010001101',
#  '1010001110',
#  '1010001111',
#  '1010010000',
#  '1010010001',
#  '1010010010',
#  '1010010011',
#  '1010010100',
#  '1010010101',
#  '1010010110',
#  '1010010111',
#  '1010011000',
#  '1010011001',
#  '1010011010',
#  '1010011011',
#  '1010011100',
#  '1010011101',
#  '1010011110',
#  '1010011111',
#  '1010100000',
#  '1010100001',
#  '1010100010',
#  '1010100011',
#  '1010100100',
#  '1010100101',
#  '1010100110',
#  '1010100111',
#  '1010101000',
#  '1010101001',
#  '1010101010',
#  '1010101011',
#  '1010101100',
#  '1010101101',
#  '1010101110',
#  '1010101111',
#  '1010110000',
#  '1010110001',
#  '1010110010',
#  '1010110011',
#  '1010110100',
#  '1010110101',
#  '1010110110',
#  '1010110111',
#  '1010111000',
#  '1010111001',
#  '1010111010',
#  '1010111011',
#  '1010111100',
#  '1010111101',
#  '1010111110',
#  '1010111111',
#  '1011000000',
#  '1011000001',
#  '1011000010',
#  '1011000011',
#  '1011000100',
#  '1011000101',
#  '1011000110',
#  '1011000111',
#  '1011001000',
#  '1011001001',
#  '1011001010',
#  '1011001011',
#  '1011001100',
#  '1011001101',
#  '1011001110',
#  '1011001111',
#  '1011010000',
#  '1011010001',
#  '1011010010',
#  '1011010011',
#  '1011010100',
#  '1011010101',
#  '1011010110',
#  '1011010111',
#  '1011011000',
#  '1011011001',
#  '1011011010',
#  '1011011011',
#  '1011011100',
#  '1011011101',
#  '1011011110',
#  '1011011111',
#  '1011100000',
#  '1011100001',
#  '1011100010',
#  '1011100011',
#  '1011100100',
#  '1011100101',
#  '1011100110',
#  '1011100111',
#  '1011101000',
#  '1011101001',
#  '1011101010',
#  '1011101011',
#  '1011101100',
#  '1011101101',
#  '1011101110',
#  '1011101111',
#  '1011110000',
#  '1011110001',
#  '1011110010',
#  '1011110011',
#  '1011110100',
#  '1011110101',
#  '1011110110',
#  '1011110111',
#  '1011111000',
#  '1011111001',
#  '1011111010',
#  '1011111011',
#  '1011111100',
#  '1011111101',
#  '1011111110',
#  '1011111111',
#  '1100000000',
#  '1100000001',
#  '1100000010',
#  '1100000011',
#  '1100000100',
#  '1100000101',
#  '1100000110',
#  '1100000111',
#  '1100001000',
#  '1100001001',
#  '1100001010',
#  '1100001011',
#  '1100001100',
#  '1100001101',
#  '1100001110',
#  '1100001111',
#  '1100010000',
#  '1100010001',
#  '1100010010',
#  '1100010011',
#  '1100010100',
#  '1100010101',
#  '1100010110',
#  '1100010111',
#  '1100011000',
#  '1100011001',
#  '1100011010',
#  '1100011011',
#  '1100011100',
#  '1100011101',
#  '1100011110',
#  '1100011111',
#  '1100100000',
#  '1100100001',
#  '1100100010',
#  '1100100011',
#  '1100100100',
#  '1100100101',
#  '1100100110',
#  '1100100111',
#  '1100101000',
#  '1100101001',
#  '1100101010',
#  '1100101011',
#  '1100101100',
#  '1100101101',
#  '1100101110',
#  '1100101111',
#  '1100110000',
#  '1100110001',
#  '1100110010',
#  '1100110011',
#  '1100110100',
#  '1100110101',
#  '1100110110',
#  '1100110111',
#  '1100111000',
#  '1100111001',
#  '1100111010',
#  '1100111011',
#  '1100111100',
#  '1100111101',
#  '1100111110',
#  '1100111111',
#  '1101000000',
#  '1101000001',
#  '1101000010',
#  '1101000011',
#  '1101000100',
#  '1101000101',
#  '1101000110',
#  '1101000111',
#  '1101001000',
#  '1101001001',
#  '1101001010',
#  '1101001011',
#  '1101001100',
#  '1101001101',
#  '1101001110',
#  '1101001111',
#  '1101010000',
#  '1101010001',
#  '1101010010',
#  '1101010011',
#  '1101010100',
#  '1101010101',
#  '1101010110',
#  '1101010111',
#  '1101011000',
#  '1101011001',
#  '1101011010',
#  '1101011011',
#  '1101011100',
#  '1101011101',
#  '1101011110',
#  '1101011111',
#  '1101100000',
#  '1101100001',
#  '1101100010',
#  '1101100011',
#  '1101100100',
#  '1101100101',
#  '1101100110',
#  '1101100111',
#  '1101101000',
#  '1101101001',
#  '1101101010',
#  '1101101011',
#  '1101101100',
#  '1101101101',
#  '1101101110',
#  '1101101111',
#  '1101110000',
#  '1101110001',
#  '1101110010',
#  '1101110011',
#  '1101110100',
#  '1101110101',
#  '1101110110',
#  '1101110111',
#  '1101111000',
#  '1101111001',
#  '1101111010',
#  '1101111011',
#  '1101111100',
#  '1101111101',
#  '1101111110',
#  '1101111111',
#  '1110000000',
#  '1110000001',
#  '1110000010',
#  '1110000011',
#  '1110000100',
#  '1110000101',
#  '1110000110',
#  '1110000111',
#  '1110001000',
#  '1110001001',
#  '1110001010',
#  '1110001011',
#  '1110001100',
#  '1110001101',
#  '1110001110',
#  '1110001111',
#  '1110010000',
#  '1110010001',
#  '1110010010',
#  '1110010011',
#  '1110010100',
#  '1110010101',
#  '1110010110',
#  '1110010111',
#  '1110011000',
#  '1110011001',
#  '1110011010',
#  '1110011011',
#  '1110011100',
#  '1110011101',
#  '1110011110',
#  '1110011111',
#  '1110100000',
#  '1110100001',
#  '1110100010',
#  '1110100011',
#  '1110100100',
#  '1110100101',
#  '1110100110',
#  '1110100111',
#  '1110101000',
#  '1110101001',
#  '1110101010',
#  '1110101011',
#  '1110101100',
#  '1110101101',
#  '1110101110',
#  '1110101111',
#  '1110110000',
#  '1110110001',
#  '1110110010',
#  '1110110011',
#  '1110110100',
#  '1110110101',
#  '1110110110',
#  '1110110111',
#  '1110111000',
#  '1110111001',
#  '1110111010',
#  '1110111011',
#  '1110111100',
#  '1110111101',
#  '1110111110',
#  '1110111111',
#  '1111000000',
#  '1111000001',
#  '1111000010',
#  '1111000011',
#  '1111000100',
#  '1111000101',
#  '1111000110',
#  '1111000111',
#  '1111001000',
#  '1111001001',
#  '1111001010',
#  '1111001011',
#  '1111001100',
#  '1111001101',
#  '1111001110',
#  '1111001111',
#  '1111010000',
#  '1111010001',
#  '1111010010',
#  '1111010011',
#  '1111010100',
#  '1111010101',
#  '1111010110',
#  '1111010111',
#  '1111011000',
#  '1111011001',
#  '1111011010',
#  '1111011011',
#  '1111011100',
#  '1111011101',
#  '1111011110',
#  '1111011111',
#  '1111100000',
#  '1111100001',
#  '1111100010',
#  '1111100011',
#  '1111100100',
#  '1111100101',
#  '1111100110',
#  '1111100111',
#  ...]

# %% [markdown]
# #### Etape 2 : conservation des combinaisons possibles
#
# On cherche maintenant à conserver uniquement les combinaisons ne dépassant pas la capacité maximale de 8 Go. Par exemple :
# - `'0000000001'` est à conserver puisqu'il s'agit uniquement de la vidéo J de 6.4 Go
# - `'1000000001'` n'est pas à conserver car le poids total de cette combinaison (vidéos A et J) vaut 4.5 + 6.4 = 10.9 Go, ce qui dépasse la capacité maximale.
#
# Pour cela, il faut d'abord associer à chaque combinaison la liste de vidéos correspondantes.
#
# **Question 9** : Ecrivez une fonction `construction_table(combi)` qui prend en paramètre une combinaison `combi` (mot binaire écrit sous forme d'une chaîne de caractères) et qui renvoie une table `table_correspondante` avec les vidéos correspondantes de `table_videos`. Quelques assertions devant être vérifiées par votre fonction sont données ci-dessous.

# %%
def construction_table(combi, table_videos):
    table_correspondante = []
    # à compléter
    for i in range(len(combi)) :  # i parcourt les indices des caractères de la chaîne combi
        if combi[i] == '1':   # si c'est un 1
            table_correspondante.append(table_videos[i])  # on ajoute la vidéo d'indice i à table_correspondante
    return table_correspondante

# %%
assert construction_table('0000000001', table_videos) == [{'nom': 'video J', 'poids': 6.4, 'valeur': 12}]
assert construction_table('1000000001', table_videos) == [{'nom': 'video A', 'poids': 4.5, 'valeur': 114},
                                                          {'nom': 'video J', 'poids': 6.4, 'valeur': 12}]
assert construction_table('1101000000', table_videos) == [{'nom': 'video A', 'poids': 4.5, 'valeur': 114},
                                                          {'nom': 'video B', 'poids': 0.63, 'valeur': 85},
                                                          {'nom': 'video D', 'poids': 0.085, 'valeur': 4}]

# %% [markdown]
# Maintenant que l'on sait construire la table de vidéos correspondant à une combinaison, on peut utiliser la fonction `poids_total` pour savoir si la table respecte ou non la capacité maximale autorisée.
#
# **Question 10** : Ecrivez une fonction `extraire_tables_valides(table_videos, poids_max)` qui renvoie une liste `tables_valides` contenant les combinaisons de vidéos de `table_videos` respectant la contrainte `poids_max` de poids maximal. Quelques assertions devant être vérifiées par votre fonction sont données ci-dessous.

# %%
def extraire_tables_valides(table_videos, poids_max):
    tables_valides = []
    # à compléter
    combinaisons = table_combinaisons(table_videos) # construction de toutes les combinaisons binaires
    for combi in combinaisons:  # pour chaque combinaison binaire
        table_correspondante = construction_table(combi, table_videos)  # construction de la table correspondante
        if poids_total(table_correspondante) <= poids_max:  # si la contrainte de poids est respectée
            tables_valides.append(table_correspondante)  # on ajoute la table à la liste de tables valides
    return tables_valides

# %%
table2 = [{'nom': 'video A', 'poids': 4.5, 'valeur': 114},
           {'nom': 'video J', 'poids': 6.4, 'valeur': 12}]

assert extraire_tables_valides(table2, 4) == [[]]
assert extraire_tables_valides(table2, 5) == [[], 
                                                         [{'nom': 'video A', 'poids': 4.5, 'valeur': 114}]]
assert extraire_tables_valides(table2, 7) == [[],
                                                         [{'nom': 'video J', 'poids': 6.4, 'valeur': 12}],
                                                         [{'nom': 'video A', 'poids': 4.5, 'valeur': 114}]]
assert extraire_tables_valides(table2, 11) == [[],
                                                          [{'nom': 'video J', 'poids': 6.4, 'valeur': 12}],
                                                          [{'nom': 'video A', 'poids': 4.5, 'valeur': 114}],
                                                          [{'nom': 'video A', 'poids': 4.5, 'valeur': 114},
                                                           {'nom': 'video J', 'poids': 6.4, 'valeur': 12}]]

# %% [markdown]
# L'appel `extraire_tables_valides(table_videos, 8)` permet de renvoyer la liste de toutes les combinaisons de vidéos d'un poids total inférieur ou égal à 8 Go. Il y en a beaucoup, voici la liste de tables valides que l'on obtient (essayez !).

# %%
tables_valides = [
    [],
    [{'nom': 'video J', 'valeur': 12, 'poids': 6.4}],
    [{'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video H', 'valeur': 74, 'poids': 3.7},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video J', 'valeur': 12, 'poids': 6.4}],
    [{'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video F', 'valeur': 80, 'poids': 2.71}],
    [{'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video E', 'valeur': 18, 'poids': 2.15}],
    [{'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71}],
    [{'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video D', 'valeur': 4, 'poids': 0.085}],
    [{'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video J', 'valeur': 12, 'poids': 6.4}],
    [{'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video J', 'valeur': 12, 'poids': 6.4}],
    [{'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71}],
    [{'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15}],
    [{'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71}],
    [{'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video C', 'valeur': 40, 'poids': 3.35}],
    [{'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71}],
    [{'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15}],
    [{'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085}],
    [{'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71}],
    [{'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15}],
    [{'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video J', 'valeur': 12, 'poids': 6.4}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video J', 'valeur': 12, 'poids': 6.4}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video J', 'valeur': 12, 'poids': 6.4}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video J', 'valeur': 12, 'poids': 6.4}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video C', 'valeur': 40, 'poids': 3.35}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video H', 'valeur': 74, 'poids': 3.7}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15}],
    [{'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video C', 'valeur': 40, 'poids': 3.35}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video C', 'valeur': 40, 'poids': 3.35},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video B', 'valeur': 85, 'poids': 0.63}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32},
    {'nom': 'video I', 'valeur': 64, 'poids': 2.4}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video F', 'valeur': 80, 'poids': 2.71}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15}],
    [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
    {'nom': 'video B', 'valeur': 85, 'poids': 0.63},
    {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
    {'nom': 'video E', 'valeur': 18, 'poids': 2.15},
    {'nom': 'video G', 'valeur': 5, 'poids': 0.32}]]

# %% [markdown]
# #### Etape 3 : trouver la meilleure solution
#
# C'est très simple : parmi les combinaisons de vidéos valides, il suffit de trouver celle dont la durée est maximale. Cela revient à faire une recherche de maximum. On parcourt toutes les combinaisons, pour chaque combinaison, on calcule la durée totale et on met à jour le maximum si besoin.
#
# **Question 11** : Ecrivez une fonction `solution_force_brute(table_video, poids_max)` qui renvoie la solution optimale au problème, c'est-à-dire la combinaison maximisant la durée totale des vidéos tout en respectant la contrainte maximale de poids.

# %%
def solution_force_brute(table_videos, poids_max):
    tables_valides = extraire_tables_valides(table_videos, poids_max) # extraction des tables valides
    # recherche de la durée maximale
    solution_optimale = tables_valides[0]  # initialisation à la première table
    duree_max = duree_totale(solution_optimale)
    for table in tables_valides:  # pour chaque table valide
        duree_table = duree_totale(table)  # on calcule sa durée totale
        if duree_table > duree_max:  # si celle-ci est plus grande que la durée max déjà trouvée
            solution_optimale = table  # cette table devient notre solution optimale
            duree_max = duree_table  # et sa durée est la nouvelle durée max de référence
    return solution_optimale, duree_max  # on renvoie la solution optimale et sa durée

# %%
solution_force_brute(table_videos, 8)
# Out:
# ([{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
#   {'nom': 'video B', 'valeur': 85, 'poids': 0.63},
#   {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
#   {'nom': 'video F', 'valeur': 80, 'poids': 2.71}],
#  283)

# %% [markdown]
# L'appel `solution_force_brute(table_videos, 8)` renvoie la solution optimale suivante d'une durée totale maximale égale à 283 minutes.
#
# ```python
# solution_optimale = [{'nom': 'video A', 'valeur': 114, 'poids': 4.5},
#                      {'nom': 'video B', 'valeur': 85, 'poids': 0.63},
#                      {'nom': 'video D', 'valeur': 4, 'poids': 0.085},
#                      {'nom': 'video F', 'valeur': 80, 'poids': 2.71}]
# ```
#
# On constate donc que la solution gloutonne $\{B, D, F, I, G\}$ d'une durée totale de 238 min (poids total : 6.145 Go) n'est pas optimale puisque la force brute prouve que l'on peut obtenir une durée totale de 283 min avec les vidéos $\{A,B, D, F\}$ (poids total 7.925 Go).
#
# >**Remarque** : il était possible d'appliquer la force brute car le nombre de vidéos de départ était petit (10), mais cela aurait été impossible pour un grand nombre de vidéos car le nombre de combinaisons à énumérer dépasserait très vite les capacités d'un ordinateur aussi puissant soit-il.

# %% [markdown]
# #### Etape 2 :

# %% [markdown]
# >**Questions**
# 1. Appliquez chacune de ces stratégies gloutonnes à la situation précédente.
# 2. Dans chaque cas, prouvez que la solution obtenue n'est pas optimale.
#
# Dans le premier cas, en choisissant les objets par valeur décroissante, l'algorithme glouton donne le sac $\{A, D\}$ d'une valeur 4800 + 500 = 5300 €.
#
# Dans le second cas, en choisissant les objets par masse croissante, l'algorithme glouton donne le sac $\{D, C, B\}$ d'une valeur 500 + 3000 + 4000 = 7500 €.
#
# Pour le dernier cas, commençons par calculer le rapport $\frac{\text{valeur}}{\text{masse}}$ de chaque objet.
#
# | objet  |  A  |  B  |  C  |  D  |
# |:------:|:---:|:---:|:---:|:---:|
# |  $\frac{\text{valeur}}{\text{masse}}$ |  600 |  800 |  750  |  500 |
#
# Ainsi, en choisissant par rapport décroissant, l'algorithme glouton donne le sac $\{B, C, D\}$ d'une valeur 7500 €.
